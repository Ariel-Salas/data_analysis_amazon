# %% [markdown]
# El dataset fue realizodo mediante un web scraping usando  Python, BeautifulSoup y WebDriver

# %% [markdown]
# Tarea principal:
#
# Explorar el conjunto de datos de ventas del dataset para responder a las preguntas de la orgsnización. Proceso de analisis recomendado para resolver este ejercicio. Primero, se limpiará y prepararán los datos para garantizar que sean precisos y coherentes. Luego, resumiremos los datos utilizando estadísticas descriptivas como promedios y rangos. Siguiendo la mism lógica, visualiremos los datos con cuadros y gráficos para ver patrones y relaciones. Detectamos valores atípicos, que son puntos de datos inusuales, y probamos nuestras suposiciones sobre los datos. Dividiremos los datos en grupos para una mejor comprensión y, finalmente, respondimos las preguntas plantedas por la organización y resumimos nuestros hallazgos.

# %% [markdown]
# Objetivos del Participante
#
# El participante deberá:
#
#
# 1. Desarrollar habilidades técnicas en análisis de datos utilizando herramientas como Python, pandas, y bibliotecas de visualización como matplotlib     y seaborn.
# 2. Aplicar técnicas de limpieza y preprocesamiento de datos, asegurando la coherencia y calidad del dataset antes de realizar análisis.
# 3. Realizar análisis estadístico descriptivo para extraer información básica como promedios, rangos, y distribuciones claves.
# 4. Explorar relaciones y patrones en los datos mediante visualizaciones interactivas y gráficas efectivas.
# 5. Identificar valores atípicos y anomalías en el conjunto de datos, comprendiendo su impacto potencial en las interpretaciones y decisiones.
# 6. Responder preguntas clave de negocio basándose en el análisis del dataset, utilizando conocimientos de estadística y visualización de datos.
# 7. Extraer insights procesables relacionados con patrones de consumo, calificaciones de productos y comportamiento de los clientes.
# 8. Fortalecer habilidades narrativas y de comunicación de datos, presentando hallazgos claros y persuasivos a través de reportes o presentaciones.
# 9. Utilizar herramientas de automatización de análisis, como el uso de JupyterLab, notebook/kaggle u otro, para documentar y reproducir resultados.
# 10. Interpretar resultados en un contexto de negocio y proponer recomendaciones en base al analisis echo. --para la toma de decisiones estratégicas-.
#
#
# Objetivos de la organización
#
# Analizar el conjunto de datos de ventas del dataset profundizando en las categorías de productos, los precios, las calificaciones y los patrones de ventas para identificar las características que resuenan en los consumidores y los impulsan a comprar.
# Categorías de productos, precios, calificaciones y patrones de ventas para identificar características que resuenan en los consumidores y los impulsan a comprar.
#
# Equipar a las orgnización con el conocimiento para crear productos que satisfagan las necesidades y deseos cambiantes de los consumidores.
# Elaborando estrategias de comunicación que resuenen con datos demográficos específicos y maximicen el compromiso.
# Facilitar un mercado donde los productos encuentren su combinación perfecta en los corazones de los consumidores.

# %% [raw]
# La organización necesita responder las siguientes preguntas:
#
# 1)¿Cuál es la calificación promedio para cada categoría de producto?
# 2)¿Cuáles son los productos con mayor cantidad de calificaciones por categoría?
# 3)¿Cuál es la distribución de precios con descuento frente a precios reales?
# 4)¿Cómo varía el porcentaje promedio de descuento entre categorías?
# 5)¿Cuáles son los nombres de producto más populares?
# 6)¿Cuáles son las palabras clave más populares de los productos?
# 7)¿Cuáles son las reseñas de producto más populares?
# 8)¿Cuál es la correlación entre el precio con descuento y la calificación?
# 9)¿Cuáles son las 5 categorías con las calificaciones más altas?
# 10)¿Cuál es el impacto de los descuentos en las ventas totales y el beneficio?
# 11)¿Cuál es la tendencia de ventas por mes o trimestre?
# 12)¿Cuáles son los clientes que generan mayor recurrencia de compras?
# 13)¿Qué productos tienen altas devoluciones o bajas calificaciones?
# 14)¿Cuál es el impacto de los tiempos de envío en la calificación promedio de los productos?
# 15)¿Qué porcentaje de ventas proviene de productos con descuentos versus sin descuentos?

# %% [markdown]
# Usaremos las siguientes bibliotecas
# 1. Pandas: manipulación y análisis de datos
# 2. Numpy: operaciones y cálculos numéricos
# 3. Matplotlib: visualización y trazado de datos
# 4. Seaborn: visualización de datos mejorada y gráficos estadísticos
# 5. Scipy: Computación científica y operaciones matemáticas avanzadas
# Se considera usar para este ejercicio el enorno de anaconda, donde se encuentra todo preinstalado

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
# this is for jupyter notebook to show the plot in the notebook itself instead of opening a new window
# %matplotlib inline

# %% [markdown]
# Pandas, que se utiliza para trabajar con datos tabulares (similar a hojas de cálculo). Es ideal para cargar, manipular y analizar datos en estructuras como DataFrames.
# Importa NumPy, una librería esencial para trabajar con arreglos/matrices multidimensionales y realizar cálculos matemáticos avanzados.
#
# Matplotlib, una librería utilizada para crear gráficos estáticos, animados e interactivos.
# pyplot es un módulo de Matplotlib que proporciona funciones para crear gráficos de forma sencilla.
#
# Seaborn, una librería construida sobre Matplotlib que facilita la creación de gráficos estadísticos. Es conocida por sus visualizaciones atractivas y fáciles de usar.
#
# SciPy, una librería utilizada para cálculos científicos y técnicos, como álgebra lineal, estadísticas y optimización.
# Es particularmente útil para pruebas estadísticas y manipulación de datos avanzados.
#
# Es un comando mágico de Jupyter Notebook que asegura que los gráficos creados con Matplotlib o Seaborn se muestren dentro del cuaderno (inline), en lugar de abrirse en ventanas externas.

# %% [markdown]
# Conexión con el dataset

# %%
try:
    # conectarse al dataset
    ruta_archivo = "C:/Users/ariel/OneDrive/Desktop/ciencia de datos/dataset/amazon.csv"
    #también podría ser encoding='latin1'
    df = pd.read_csv(ruta_archivo, encoding='utf-8')
    print("Conexión exitosa: el archivo se cargó correctamente.")
    print(f"El archivo tiene {len(df)} filas y {len(df.columns)} columnas.")
except FileNotFoundError:
    print("Error: No se encontró el archivo en la ruta especificada.")
except Exception as e:
    print(f"Error al conectar con el dataset: {e}")
# Out:
# Conexión exitosa: el archivo se cargó correctamente.
# El archivo tiene 1465 filas y 16 columnas.

# %% [markdown]
# mostrar la mayor cantidad de de columnas

# %% [markdown]
# sneak peek (adelanto de los datos)
# El propósito de un adelanto es obtener una descripción general rápida de los datos e identificar posibles problemas o áreas de interés.

# %%
pd.set_option('display.max_columns',None)

# %%
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
df.tail(3)
# Out:
#       product_id                                       product_name  \
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 1462  Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...           ₹2,219
# 1463  Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...           ₹1,399
# 1464  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹2,863
#
#      actual_price discount_percentage rating rating_count  \
# 1462       ₹3,080                 28%    3.6          468
# 1463       ₹1,890                 26%      4        8,031
# 1464       ₹3,690                 22%    4.3        6,987
#
#                                           about_product  \
# 1462  International design and styling|Two heat sett...
# ...

# %%
df.describe()
# Out:
#         product_id                                       product_name  \
# count         1465                                               1465
# unique        1351                                               1337
# top     B07JW9H4J1  Fire-Boltt Ninja Call Pro Plus 1.83" Smart Wat...
# freq             3                                                  5
#
#                                                  category discounted_price  \
# count                                                1465             1465
# unique                                                211              550
# top     Computers&Accessories|Accessories&Peripherals|...             ₹199
# freq                                                  233               53
#
#        actual_price discount_percentage rating rating_count  \
# count          1465                1465   1465         1463
# unique          449                  92     28         1143
# ...

# %%
#podemos ver las columnas del dataset
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
#podemos saber el numero de filas y columnas  del dataset

# %%
print(f"The Number of Rows are {df.shape[0]}, and columns are {df.shape[1]}.")
# Out:
# The Number of Rows are 1465, and columns are 16.

# %%
#Veremos las columnas y sus tipos de datos usando la función de información detallada.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %% [markdown]
# explicacaion: La salida de df.info() en pandas proporciona un resumen detallado del dataframe, permitiéndonos entender su estructura, el número de filas, columnas, tipos de datos y datos faltantes.
# Analisemoslo paso a paso:
# class 'pandas.core.frame.DataFrame'>
# Esto indica que df es un objeto de tipo DataFrame, que es una estructura tabular de datos en pandas.
# RangeIndex: 1465 entries, 0 to 1464
# El índice de este DataFrame es un RangeIndex, que significa que las filas están indexadas de manera predeterminada de 0 a 1464 (totalizando 1465 filas).
# 2. Resumen de las columnas: Data columns (total 16 columns):
# El DataFrame tiene un total de 16 columnas.
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
# #: El número de la columna (empezando desde 0).
# Column: El nombre de cada columna en el DataFrame.
# Non-Null Count: La cantidad de filas no nulas en cada columna.
# Dtype: El tipo de datos almacenados en esa columna.
#
# Desglose de columnas
# 0   product_id           1465 non-null   object
#
# product_id: Contiene 1465 valores no nulos, y su tipo de dato es object (que en pandas representa cadenas de texto u objetos generales).
#  1   product_name         1465 non-null   object
#
#  7   rating_count         1463 non-null   object
#
# La columna rating_count tiene 1463 valores no nulos, lo que significa que 2 valores están faltando (1465 - 1463).
#
# 3. Tipos de datos (dtypes)
# dtypes: object(16)
#
# Todas las columnas son de tipo object. Esto puede significar que contienen texto, pero también que columnas como discounted_price, actual_price,
# discount_percentage o rating son texto en lugar de valores numéricos, lo cual podría requerir conversión para análisis.
#
# 4. Uso de memoria
# memory usage: 183.3+ KB
#
# Indica que el DataFrame ocupa 183.3 KB de memoria en el sistema.
#
# Análisis y pasos siguientes
#
#     Validar valores nulos:
#         La columna rating_count tiene valores nulos, por lo que debemos decidir si imputarlos (rellenarlos con valores calculados) o eliminarlos.
#
#     Convertir datos a tipos correctos:
#         Muchas columnas (discounted_price, actual_price, rating, etc.) deberían ser numéricas para análisis. Convertiremos estas columnas de object a tipos numéricos (como float o int) si es necesario.
#
#     Examinar datos faltantes y anómalos:
#         Revisaremos los valores para garantizar que no haya errores, como precios no válidos o calificaciones fuera de rango.
#
#     Preparar datos para análisis:
#         Una vez que las conversiones y limpiezas estén completas, el DataFrame estará listo para estadísticas descriptivas y visualizaciones.

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# 1. df.isnull()
#
#     df.isnull() genera un DataFrame de valores booleanos (True/False) donde:
#         True indica que en esa celda del DataFrame hay un valor nulo o faltante (NaN).
#         False indica que la celda tiene un valor presente (no nulo).
#
#     Este método devuelve un DataFrame del mismo tamaño que el original, pero con valores True y False según la presencia de valores nulos.
#
# 2. .sum()
#
#     Al aplicar .sum() después de df.isnull(), estamos sumando los valores True en cada columna. En Python, True se considera como 1 y False como 0, por lo que cuando sumamos los valores de True, obtenemos el número total de valores nulos en cada columna.
#         Por ejemplo, si una columna tiene 2 valores True (nulos) y 10 valores False (no nulos), el resultado para esa columna será 2. Que es justamente lo que pasa en rating_count que tiene el valor de 2

# %% [markdown]
# Primeras impresiones:
# Hay 1465 filas y 16 columnas en el conjunto de datos.
# El tipo de datos de todas las columnas es objeto.
# Las columnas de los conjuntos de datos son:
# 'id_producto', 'nombre_producto', 'categoría', 'precio_descuento', 'precio_actual', 'porcentaje_descuento', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title ', 'review_content', 'img_link', 'product_link'
#
# Faltan algunos valores en el conjunto de datos, como en la columna rating_count,  que leeremos en detalle y trataremos más adelante

# %% [markdown]
# Cambiar tipos de datos de columnas de objeto a flotante

# %%
# Cambiar el tipo de datos de precio con descuento y precio real

df['discounted_price'] = df['discounted_price'].str.replace("₹",'')
df['discounted_price'] = df['discounted_price'].str.replace(",",'')
df['discounted_price'] = df['discounted_price'].astype('float64')

df['actual_price'] = df['actual_price'].str.replace("₹",'')
df['actual_price'] = df['actual_price'].str.replace(",",'')
df['actual_price'] = df['actual_price'].astype('float64')

# %%
df.head(3)
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
#
#                                             category  discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             399.0
# 1  Computers&Accessories|Accessories&Peripherals|...             199.0
# 2  Computers&Accessories|Accessories&Peripherals|...             199.0
#
#    actual_price discount_percentage rating rating_count  \
# 0        1099.0                 64%    4.2       24,269
# 1         349.0                 43%    4.0       43,994
# 2        1899.0                 90%    3.9        7,928
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# ...

# %%
# Importar las bibliotecas necesarias
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go

# Cargar el dataset
file_path = "C:/Users/ariel/OneDrive/Desktop/ciencia de datos/dataset/amazon.csv"
df = pd.read_csv(file_path)

# Limpieza de datos: transformar columnas a formatos numéricos
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')  # Convertir ratings a números, ignorando errores

# Filtrar valores nulos y anómalos
df_cleaned = df.dropna(subset=['actual_price', 'discounted_price', 'rating'])

# Crear la gráfica interactiva en 3D
fig = px.scatter_3d(
    df_cleaned,
    x='actual_price',       # Eje X: Precio original
    y='discounted_price',   # Eje Y: Precio con descuento
    z='rating',             # Eje Z: Calificación
    color='rating',         # Colorear por calificación
    hover_name='product_name',  # Mostrar nombre del producto al pasar el mouse
    title='Relación entre Precios y Calificaciones de Productos'
)

# Ajustar el tamaño del gráfico y los puntos
fig.update_layout(
    width=1200,  # Ancho del gráfico
    height=800,  # Altura del gráfico
    scene=dict(
        xaxis=dict(title='Precio Original', color='red'),  # Eje X en rojo
        yaxis=dict(title='Precio Descuento', color='green'),  # Eje Y en verde
        zaxis=dict(title='Calificación', color='blue')  # Eje Z en azul
    )
)

# Reducir el tamaño de los puntos
fig.update_traces(marker=dict(size=3))  # Tamaño de los puntos reducido

# Agregar flechas a los ejes
fig.add_trace(
    go.Scatter3d(
        x=[df_cleaned['actual_price'].max()], 
        y=[0], 
        z=[0], 
        mode='markers+text',
        marker=dict(size=5, color='red'),
        text=['Eje X →'],
        textposition="middle right",
        showlegend=False
    )
)
fig.add_trace(
    go.Scatter3d(
        x=[0], 
        y=[df_cleaned['discounted_price'].max()], 
        z=[0], 
        mode='markers+text',
        marker=dict(size=5, color='green'),
        text=['Eje Y →'],
        textposition="middle right",
        showlegend=False
    )
)
fig.add_trace(
    go.Scatter3d(
        x=[0], 
        y=[0], 
        z=[df_cleaned['rating'].max()], 
        mode='markers+text',
        marker=dict(size=5, color='blue'),
        text=['Eje Z →'],
        textposition="middle right",
        showlegend=False
    )
)

# Mostrar la gráfica
fig.show()

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# Cargar el dataset
file_path = "C:/Users/ariel/OneDrive/Desktop/ciencia de datos/dataset/amazon.csv"
df = pd.read_csv(file_path)

# Limpieza de datos: transformar columnas a formatos numéricos
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')  # Convertir ratings a números, ignorando errores

# Filtrar valores nulos y anómalos
df_cleaned = df.dropna(subset=['actual_price', 'discounted_price', 'rating'])

# Crear la gráfica interactiva en 3D
fig = px.scatter_3d(
    df_cleaned,
    x='actual_price',       # Eje X: Precio original
    y='discounted_price',   # Eje Y: Precio con descuento
    z='rating',             # Eje Z: Calificación
    color='rating',         # Colorear por calificación
    hover_name='product_name',  # Mostrar nombre del producto al pasar el mouse
    title='Relación entre Precios y Calificaciones de Productos'
)

# Ajustar el tamaño del gráfico y los puntos
fig.update_layout(
    width=1200,  # Ancho del gráfico
    height=800,  # Altura del gráfico
    scene=dict(
        xaxis=dict(title='Precio Original', color='red'),  # Eje X en rojo
        yaxis=dict(title='Precio Descuento', color='green'),  # Eje Y en verde
        zaxis=dict(title='Calificación', color='blue')  # Eje Z en azul
    )
)

# Reducir el tamaño de los puntos
fig.update_traces(marker=dict(size=3))  # Tamaño de los puntos reducido

# Mostrar la gráfica
fig.show()

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# Cargar el dataset
file_path = "C:/Users/ariel/OneDrive/Desktop/ciencia de datos/dataset/amazon.csv"
df = pd.read_csv(file_path)

# Limpieza de datos: transformar columnas a formatos numéricos
df['actual_price'] = df['actual_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['discounted_price'] = df['discounted_price'].str.replace('₹', '').str.replace(',', '').astype(float)
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')  # Convertir ratings a números, ignorando errores

# Filtrar valores nulos y anómalos
df_cleaned = df.dropna(subset=['actual_price', 'discounted_price', 'rating'])

# Crear la gráfica interactiva en 3D
fig = px.scatter_3d(
    df_cleaned,
    x='actual_price',       # Eje X: Precio original
    y='discounted_price',   # Eje Y: Precio con descuento
    z='rating',             # Eje Z: Calificación
    color='rating',         # Colorear por calificación
    hover_name='product_name',  # Mostrar nombre del producto al pasar el mouse
    title='Relación entre Precios y Calificaciones de Productos'
)

# Ajustar el tamaño del gráfico y los puntos
fig.update_layout(
    width=1200,
    height=800,
    scene=dict(
        xaxis=dict(title='Precio Original'),
        yaxis=dict(title='Precio Descuento'),
        zaxis=dict(title='Calificación')
    )
)

# Agregar botones para cambiar vistas
fig.update_layout(
    updatemenus=[
        dict(
            type="buttons",
            direction="left",
            x=0.1,
            y=1.2,
            buttons=[
                dict(
                    label="Vista Frontal",
                    method="relayout",
                    args=["scene.camera", {
                        "eye": {"x": 0, "y": 0, "z": 2.5}  # Frontal
                    }]
                ),
                dict(
                    label="Vista Lateral",
                    method="relayout",
                    args=["scene.camera", {
                        "eye": {"x": 2.5, "y": 0, "z": 0}  # Lateral
                    }]
                ),
                dict(
                    label="Vista Superior",
                    method="relayout",
                    args=["scene.camera", {
                        "eye": {"x": 0, "y": 2.5, "z": 0}  # Superior
                    }]
                ),
            ]
        )
    ]
)

# Mostrar la gráfica
fig.show()
